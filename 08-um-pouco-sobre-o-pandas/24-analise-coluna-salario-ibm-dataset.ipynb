# %% [markdown]
# ### Preparativos do Dataset (remoção de colunas sem variação de valores e categorizando as colunas ordenadas e não ordenadas)

# %%
import pandas as pd

BASE = "../datasets/HR-Employee-Attrition.csv"

df = pd.read_csv(BASE)


# Limpando a base de colunas com valores não variam e removendo a
# coluna de identificação (EmployeeNumber)

df = df.drop("EmployeeNumber", axis=1)

for c in df.columns:
    column = df[c]
    if (column.nunique() <= 1):
        print(f"Removendo coluna {c}") 
        df = df.drop(c, axis=1)


# Separando nossas colunas por variáveis categóricas ordenadas e 
# não ordernadas


# Colunas que são categóricas e não ordenadas
columns_categorical_not_ordered = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime'
]

# Colunas que são categóricas e ordernadas
columns_categorical_ordered = [
    'Education',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance',
    'JobInvolvement'
]

target_column = ['Attrition']


numeric_columns = [
    column
    for column in df.columns
    if column not in (columns_categorical_ordered + columns_categorical_not_ordered + target_column)
]


# Convertendo nossas colunas não ordernadas para o tipo category

for column in columns_categorical_not_ordered:
    df[column] = df[column].astype("category")
# Out:
# Removendo coluna EmployeeCount
# Removendo coluna Over18
# Removendo coluna StandardHours

# %% [markdown]
# ### Análise da coluna salário
#
# Vamos considerar a coluna "MonthlyIncome" como a coluna salário, podemos verificar a média salarial por departamento:

# %%
df.groupby("Department", observed=True)["MonthlyIncome"].mean()
# Out:
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# Podemos ver um certo padrão se fizermos um agrupamento com a coluna "Attrition"

# %%
df.groupby(["Department", "Attrition"], observed=True)["MonthlyIncome"].mean()
# Out:
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# É possível concluir com base nos dados acima de que a média salarial de funcionários que saíram da empresa é menor do que a de funcionários que permaneceram.

# %% [markdown]
# #### Reproduzindo o cenário acima utilizando o pivot_table

# %%
df.pivot_table(index="Department", columns="Attrition", values="MonthlyIncome")
# Out:
# Attrition                        No          Yes
# Department
# Human Resources         7345.980392  3715.750000
# Research & Development  6630.326087  4108.075188
# Sales                   7232.240113  5908.456522

# %% [markdown]
# #### Visualizando a média salarial por cargo

# %%
df.groupby("JobRole", observed=True)["MonthlyIncome"].mean()

# %% [markdown]
# #### Visualizando a média salarial por cargo + nível do cargo

# %%
df.groupby(["JobRole", "JobLevel"], observed=True)["MonthlyIncome"].mean()
# Out:
# JobRole                    JobLevel
# Healthcare Representative  2            5865.346154
#                            3            9363.954545
#                            4           12973.000000
# Human Resources            1            2733.212121
#                            2            5563.461538
#                            3            9623.000000
# Laboratory Technician      1            2854.590000
#                            2            4455.625000
#                            3            5998.000000
# Manager                    3           12233.000000
#                            4           16613.276596
#                            5           19183.976744
# Manufacturing Director     2            5612.755556
#                            3            9307.044444
#                            4           13383.000000
# Research Director          3           12721.571429
#                            4           16429.038462
#                            5           19204.807692
# Research Scientist         1            2827.649573
#                            2            4818.912281
#                            3            9724.000000
# Sales Executive            2            5800.884120
#                            3            9124.987342
#                            4           13202.500000
# Sales Representative       1            2506.723684
#                            2            3921.000000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# #### Convertendo o retorno do groupby para um DataFrame utilizando o .to_frame()

# %%
df_mean_by_job_role_and_level = df.groupby(["JobRole", "JobLevel"], observed=True)["MonthlyIncome"].mean()
df_mean_by_job_role_and_level = df_mean_by_job_role_and_level.to_frame()
df_mean_by_job_role_and_level
# Out:
#                                     MonthlyIncome
# JobRole                   JobLevel
# Healthcare Representative 2           5865.346154
#                           3           9363.954545
#                           4          12973.000000
# Human Resources           1           2733.212121
#                           2           5563.461538
#                           3           9623.000000
# Laboratory Technician     1           2854.590000
#                           2           4455.625000
#                           3           5998.000000
# Manager                   3          12233.000000
#                           4          16613.276596
#                           5          19183.976744
# Manufacturing Director    2           5612.755556
#                           3           9307.044444
#                           4          13383.000000
# Research Director         3          12721.571429
#                           4          16429.038462
#                           5          19204.807692
# Research Scientist        1           2827.649573
#                           2           4818.912281
#                           3           9724.000000
# Sales Executive           2           5800.884120
#                           3           9124.987342
#                           4          13202.500000
# Sales Representative      1           2506.723684
#                           2           3921.000000

# %% [markdown]
# Para facilitar o entendimento de forma visual de maiores e menores salários podemos utilizar o style

# %%
df_mean_by_job_role_and_level.style.background_gradient(cmap="RdYlGn", axis="index")
# Out:
# <style type="text/css">
# #T_0d38a_row0_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_0d38a_row1_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_0d38a_row2_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_0d38a_row3_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_0d38a_row4_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_0d38a_row5_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_0d38a_row6_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_0d38a_row7_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_0d38a_row8_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_0d38a_row9_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_0d38a_row10_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_0d38a_row11_col0, #T_0d38a_row17_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0d38a_row12_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_0d38a_row13_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_0d38a_row14_col0 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_0d38a_row15_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_0d38a_row16_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_0d38a_row18_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_0d38a_row19_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_0d38a_row20_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_0d38a_row21_col0 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_0d38a_row22_col0 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_0d38a_row23_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_0d38a_row24_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0d38a_row25_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0d38a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d38a_level0_col0" class="col_heading level0 col0" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d38a_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_0d38a_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_0d38a_row0_col0" class="data row0 col0" >5865.346154</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_0d38a_row1_col0" class="data row1 col0" >9363.954545</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_0d38a_row2_col0" class="data row2 col0" >12973.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_0d38a_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_0d38a_row3_col0" class="data row3 col0" >2733.212121</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_0d38a_row4_col0" class="data row4 col0" >5563.461538</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_0d38a_row5_col0" class="data row5 col0" >9623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_0d38a_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_0d38a_row6_col0" class="data row6 col0" >2854.590000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_0d38a_row7_col0" class="data row7 col0" >4455.625000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_0d38a_row8_col0" class="data row8 col0" >5998.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_0d38a_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_0d38a_row9_col0" class="data row9 col0" >12233.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_0d38a_row10_col0" class="data row10 col0" >16613.276596</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_0d38a_row11_col0" class="data row11 col0" >19183.976744</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_0d38a_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_0d38a_row12_col0" class="data row12 col0" >5612.755556</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_0d38a_row13_col0" class="data row13 col0" >9307.044444</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_0d38a_row14_col0" class="data row14 col0" >13383.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_0d38a_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_0d38a_row15_col0" class="data row15 col0" >12721.571429</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_0d38a_row16_col0" class="data row16 col0" >16429.038462</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_0d38a_row17_col0" class="data row17 col0" >19204.807692</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_0d38a_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_0d38a_row18_col0" class="data row18 col0" >2827.649573</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_0d38a_row19_col0" class="data row19 col0" >4818.912281</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_0d38a_row20_col0" class="data row20 col0" >9724.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_0d38a_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_0d38a_row21_col0" class="data row21 col0" >5800.884120</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_0d38a_row22_col0" class="data row22 col0" >9124.987342</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row23" class="row_heading level1 row23" >4</th>
#       <td id="T_0d38a_row23_col0" class="data row23 col0" >13202.500000</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level0_row24" class="row_heading level0 row24" rowspan="2">Sales Representative</th>
#       <th id="T_0d38a_level1_row24" class="row_heading level1 row24" >1</th>
#       <td id="T_0d38a_row24_col0" class="data row24 col0" >2506.723684</td>
#     </tr>
#     <tr>
#       <th id="T_0d38a_level1_row25" class="row_heading level1 row25" >2</th>
#       <td id="T_0d38a_row25_col0" class="data row25 col0" >3921.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# É interessante analisar que o cargo "Sales Representative" tem o menor salário (o teto é em média 3921) e é também a área onde o "Attrtion" é maior conforme vimos com o crosstab

# %%
pd.crosstab(df["Department"], df["Attrition"], normalize="index")
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %% [markdown]
# Proporcionalmente falando a maior média de "Attrition" é para a área de vendas, são 21%.
