# %% [markdown]
# ### Preparativos do Dataset (remoção de colunas sem variação de valores e categorizando as colunas ordenadas e não ordenadas)

# %%
import pandas as pd

BASE = "../datasets/HR-Employee-Attrition.csv"

df = pd.read_csv(BASE)


# Limpando a base de colunas com valores não variam e removendo a
# coluna de identificação (EmployeeNumber)

df = df.drop("EmployeeNumber", axis=1)

for c in df.columns:
    column = df[c]
    if (column.nunique() <= 1):
        print(f"Removendo coluna {c}") 
        df = df.drop(c, axis=1)


# Separando nossas colunas por variáveis categóricas ordenadas e 
# não ordernadas


# Colunas que são categóricas e não ordenadas
columns_categorical_not_ordered = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime'
]

# Colunas que são categóricas e ordernadas
columns_categorical_ordered = [
    'Education',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance',
    'JobInvolvement'
]

target_column = ['Attrition']


numeric_columns = [
    column
    for column in df.columns
    if column not in (columns_categorical_ordered + columns_categorical_not_ordered + target_column)
]


# Convertendo nossas colunas não ordernadas para o tipo category

for column in columns_categorical_not_ordered:
    df[column] = df[column].astype("category")
# Out:
# Removendo coluna EmployeeCount
# Removendo coluna Over18
# Removendo coluna StandardHours

# %% [markdown]
# ### Análise coluna MonthlyIncome e outras columas com o crosstab

# %% [markdown]
# Podemos utilizar mais de duas colunas com o crosstab, basta passarmos uma lista como argumento, no exemplo abaixo vamos ver a relação de "Attrition" com "JobRole" + "JobLevel":

# %%
pd.crosstab(
    [ df["JobRole"], df["JobLevel"] ], # Uma lista de colunas
    df["Attrition"],
    normalize="index"
)
# Out:
# Attrition                                 No       Yes
# JobRole                   JobLevel
# Healthcare Representative 2         0.961538  0.038462
#                           3         0.886364  0.113636
#                           4         0.888889  0.111111
# Human Resources           1         0.696970  0.303030
#                           2         1.000000  0.000000
#                           3         0.666667  0.333333
# Laboratory Technician     1         0.720000  0.280000
#                           2         0.910714  0.089286
#                           3         0.666667  0.333333
# Manager                   3         0.833333  0.166667
#                           4         1.000000  0.000000
#                           5         0.930233  0.069767
# Manufacturing Director    2         0.944444  0.055556
#                           3         0.888889  0.111111
#                           4         1.000000  0.000000
# Research Director         3         1.000000  0.000000
#                           4         1.000000  0.000000
#                           5         0.923077  0.076923
# Research Scientist        1         0.807692  0.192308
#                           2         0.964912  0.035088
#                           3         1.000000  0.000000
# Sales Executive           2         0.845494  0.154506
#                           3         0.784810  0.215190
#                           4         0.714286  0.285714
# Sales Representative      1         0.578947  0.421053
#                           2         0.857143  0.142857

# %% [markdown]
# ### Utilizando o style com vmin e vmax
#
# Para visualizar a tabela acima de uma maneira mais autoexplicativa sabemos que podemos utilizar a propriedade style com o mapa de calor do matplotlib, mas somado a isso existem os argumentos `vmin` e `vmax` que ao enviarmos para a função .background_gradient vão deixar a entonação das cores mais variadas, destacando assim dados extremos:

# %%
pd.crosstab(
    [ df["JobRole"], df["JobLevel"] ], # Uma lista de colunas
    df["Attrition"],
    normalize="index"
).style.background_gradient(cmap="RdYlGn", axis="columns", vmin=0, vmax=1)
# Out:
# <style type="text/css">
# #T_cf0f7_row0_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_cf0f7_row0_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_cf0f7_row1_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_cf0f7_row1_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_cf0f7_row2_col0, #T_cf0f7_row13_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_cf0f7_row2_col1, #T_cf0f7_row13_col1 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_cf0f7_row3_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_cf0f7_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_cf0f7_row4_col0, #T_cf0f7_row10_col0, #T_cf0f7_row14_col0, #T_cf0f7_row15_col0, #T_cf0f7_row16_col0, #T_cf0f7_row20_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cf0f7_row4_col1, #T_cf0f7_row10_col1, #T_cf0f7_row14_col1, #T_cf0f7_row15_col1, #T_cf0f7_row16_col1, #T_cf0f7_row20_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_cf0f7_row5_col0, #T_cf0f7_row8_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_cf0f7_row5_col1, #T_cf0f7_row8_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_cf0f7_row6_col0 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_cf0f7_row6_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_cf0f7_row7_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_cf0f7_row7_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_cf0f7_row9_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_cf0f7_row9_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_cf0f7_row11_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_cf0f7_row11_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_cf0f7_row12_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_cf0f7_row12_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_cf0f7_row17_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_cf0f7_row17_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_cf0f7_row18_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_cf0f7_row18_col1 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_cf0f7_row19_col0 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_cf0f7_row19_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_cf0f7_row21_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_cf0f7_row21_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_cf0f7_row22_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_cf0f7_row22_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_cf0f7_row23_col0 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_cf0f7_row23_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_cf0f7_row24_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_cf0f7_row24_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_cf0f7_row25_col0 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_cf0f7_row25_col1 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf0f7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_cf0f7_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_cf0f7_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf0f7_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_cf0f7_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_cf0f7_row0_col0" class="data row0 col0" >0.961538</td>
#       <td id="T_cf0f7_row0_col1" class="data row0 col1" >0.038462</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_cf0f7_row1_col0" class="data row1 col0" >0.886364</td>
#       <td id="T_cf0f7_row1_col1" class="data row1 col1" >0.113636</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_cf0f7_row2_col0" class="data row2 col0" >0.888889</td>
#       <td id="T_cf0f7_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_cf0f7_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_cf0f7_row3_col0" class="data row3 col0" >0.696970</td>
#       <td id="T_cf0f7_row3_col1" class="data row3 col1" >0.303030</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_cf0f7_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_cf0f7_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_cf0f7_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_cf0f7_row5_col1" class="data row5 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_cf0f7_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_cf0f7_row6_col0" class="data row6 col0" >0.720000</td>
#       <td id="T_cf0f7_row6_col1" class="data row6 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_cf0f7_row7_col0" class="data row7 col0" >0.910714</td>
#       <td id="T_cf0f7_row7_col1" class="data row7 col1" >0.089286</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_cf0f7_row8_col0" class="data row8 col0" >0.666667</td>
#       <td id="T_cf0f7_row8_col1" class="data row8 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_cf0f7_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_cf0f7_row9_col0" class="data row9 col0" >0.833333</td>
#       <td id="T_cf0f7_row9_col1" class="data row9 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_cf0f7_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_cf0f7_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_cf0f7_row11_col0" class="data row11 col0" >0.930233</td>
#       <td id="T_cf0f7_row11_col1" class="data row11 col1" >0.069767</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_cf0f7_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_cf0f7_row12_col0" class="data row12 col0" >0.944444</td>
#       <td id="T_cf0f7_row12_col1" class="data row12 col1" >0.055556</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_cf0f7_row13_col0" class="data row13 col0" >0.888889</td>
#       <td id="T_cf0f7_row13_col1" class="data row13 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_cf0f7_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_cf0f7_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_cf0f7_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_cf0f7_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_cf0f7_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf0f7_level1_row16"
